# %%
# Calculate Watt Spectra weighting given a set of input bins
import csv    # Library to read & process csv-formatted files
import sys    # Library to parse command-line arguments
import os
from math import sqrt, sinh, pi, exp
import numpy as np

rootdir=os.path.abspath(os.getcwd())

# Optional Paramater set - ref=Verbeke2014
# Assume avg fission energy of 1 MeV for benchmark of the Watt induced FP distibution
a0=0.925496
a1=-0.0106491
a2=8.96945e-05
b=1.0
En=1.0
fname = rootdir+"/Bins.csv"   # Bin structure input file

# Read in the bin structure from file
try: 
    ifile = open(fname, 'r') 
    ifile.next() # skip the first header line

    # Store the spectrum
    bins=[]
    for line in ifile:
        split_list=line.split(',')
        bins.append(float(split_list[2].strip()))

    # Close the file
    ifile.close()
except IOError as e:
    print "I/O error({0}): {1}".format(e.errno, e.strerror)
    print "File not found was: {0}".format(fname)
    
# Calculate the Watt spectra
def Watt(E,a0,a1,a2,b,E_inc):
    a=a0+a1*E_inc+a2*E_inc**2
    c=sqrt(pi*b/(4*a))*exp(b/(4*a))/a
    w=c*exp(-a*E)*sinh(sqrt(b*E))
    return w

watt=[]
for e in bins:
    watt.append(Watt(e,a0,a1,a2,b,En))
    
np.asarray(watt)
watt=watt/np.sum(watt)

# %%
y={}
err={}

w=[]
fy=[]

one=0
two=0

# Use weighted watt spectra to generate mass yield curves (sum yields)
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        if file=="GEF.dat":
            print subdir, file
            weight = 0
            one+=1
            try: 
                ifile = open(subdir+'/'+file, 'r') 
                for line in ifile:
                    if line[:7] == ' formed':
                        split_list=line.split(' ')
                        for i in range(0,len(bins)):
                            if bins[i] == float(split_list[8].strip()):
                                two+=1
                                weight=watt[i]
                                print "Energy =", bins[i]
                                print "Fractional weight=",weight
                    if line[:27] =='--- Mass-yield distribution':
                        for i in range(0,6):
                            line=ifile.next()
                        while line[:22] != '        </Mass_yields>':
                            split_list=line.split()
                            if not split_list[0] in y.keys():  # this is the first time we've encountered this mass A
                            # let's initialize our dictionaries
                                y[split_list[0]] = float(split_list[2])*weight
                                err[split_list[0]] = (float(split_list[3])*weight)**2
                            else:  # we've encoutered this mass before, no need to initialize, just add to it
                                y[split_list[0]] += float(split_list[2])*weight
                                err[split_list[0]] += (float(split_list[3])*weight)**2
                                
                            if int(split_list[0])==140:
                                w.append(weight)
                                fy.append(float(split_list[2]))
                            line=ifile.next()
                # Close the file
                ifile.close()
            except IOError as e:
                print "I/O error({0}): {1}".format(e.errno, e.strerror)
                print "File not found was: {0}".format(fname)
print y
print y.keys()
print one
print two
# Out:
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E1.99e-005MeV GEF.dat
# Energy = 1.99e-05
# Fractional weight= 0.000630724104187
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.46MeV GEF.dat
# Energy = 0.46
# Fractional weight= 0.067891621364
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E1.03MeV GEF.dat
# Energy = 1.03
# Fractional weight= 0.0660260254417
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E10.5MeV GEF.dat
# Energy = 10.5
# Fractional weight= 0.00012128387963
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E14.6MeV GEF.dat
# Energy = 14.6
# Fractional weight= 5.09659169563e-06
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.891MeV GEF.dat
# Energy = 0.891
# Fractional weight= 0.0682333278265
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E6.52e-005MeV GEF.dat
# Energy = 6.52e-05
# Fractional weight= 0.00114162104773
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.202MeV GEF.dat
# Energy = 0.202
# Fractional weight= 0.0546202894149
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E4.84MeV GEF.dat
# Energy = 4.84
# Fractional weight= 0.00752123180808
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.308MeV GEF.dat
# Energy = 0.308
# Fractional weight= 0.0622844453779
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E12.4MeV GEF.dat
# Energy = 12.4
# Fractional weight= 2.82588626912e-05
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.0233MeV GEF.dat
# Energy = 0.0233
# Fractional weight= 0.0212091967309
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E5.67MeV GEF.dat
# Energy = 5.67
# Fractional weight= 0.00423456182974
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.0161MeV GEF.dat
# Energy = 0.0161
# Fractional weight= 0.0177255476305
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E14MeV GEF.dat
# Energy = 14.0
# Fractional weight= 8.15078441341e-06
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E11.6MeV GEF.dat
# Energy = 11.6
# Fractional weight= 5.23338330339e-05
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.000188MeV GEF.dat
# Energy = 0.000188
# Fractional weight= 0.00193837226706
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E1.27MeV GEF.dat
# Energy = 1.27
# Fractional weight= 0.0610949209318
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E2.07MeV GEF.dat
# Energy = 2.07
# Fractional weight= 0.0423211201721
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.134MeV GEF.dat
# Energy = 0.134
# Fractional weight= 0.0468147690285
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E7.8MeV GEF.dat
# Energy = 7.8
# Fractional weight= 0.000914809671828
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.00229MeV GEF.dat
# Energy = 0.00229
# Fractional weight= 0.00675449532857
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.0818MeV GEF.dat
# Energy = 0.0818
# Fractional weight= 0.0380362280901
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E9.52MeV GEF.dat
# Energy = 9.52
# Fractional weight= 0.000254498122067
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E13.2MeV GEF.dat
# Energy = 13.2
# Fractional weight= 1.52023517716e-05
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.000909MeV GEF.dat
# Energy = 0.000909
# Fractional weight= 0.00425996371206
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E6.89MeV GEF.dat
# Energy = 6.89
# Fractional weight= 0.00177549915531
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E1.62MeV GEF.dat
# Energy = 1.62
# Fractional weight= 0.0528415487681
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E4.39MeV GEF.dat
# Energy = 4.39
# Fractional weight= 0.0101938276346
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.595MeV GEF.dat
# Energy = 0.595
# Fractional weight= 0.0697425318076
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E15.9MeV GEF.dat
# Energy = 15.9
# Fractional weight= 1.83267414491e-06
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E7.7e-007MeV GEF.dat
# Energy = 7.7e-07
# Fractional weight= 0.000124069339342
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E3.54MeV GEF.dat
# Energy = 3.54
# Fractional weight= 0.0177698177625
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E2.35MeV GEF.dat
# Energy = 2.35
# Fractional weight= 0.0363616704986
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.00684MeV GEF.dat
# Energy = 0.00684
# Fractional weight= 0.011633877966
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E18.3MeV GEF.dat
# Energy = 18.3
# Fractional weight= 2.72654306852e-07
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E8.62MeV GEF.dat
# Energy = 8.62
# Fractional weight= 0.000498967298398
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E2.09e-006MeV GEF.dat
# Energy = 2.09e-06
# Fractional weight= 0.000204405144112
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E2.07e-007MeV GEF.dat
# Energy = 2.07e-07
# Fractional weight= 6.4328653756e-05
# Energy = 2.07e-07
# Fractional weight= 6.4328653756e-05
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.0295MeV GEF.dat
# Energy = 0.0295
# Fractional weight= 0.023754268946
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E2.7MeV GEF.dat
# Energy = 2.7
# Fractional weight= 0.0297582874347
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.0434MeV GEF.dat
# Energy = 0.0434
# Fractional weight= 0.0285138600473
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E6.87e-006MeV GEF.dat
# Energy = 6.87e-06
# Fractional weight= 0.000370591533535
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0.782MeV GEF.dat
# Energy = 0.782
# Fractional weight= 0.0694209171692
# /home/pyne-user/Dropbox/UCB/Research/ETAs/Scoping_Calcs/FP_Distro/Validation/238Watt/Z92_A239_n_E0
811910935962, '141': 5.6475859400632906, '148': 2.1010942087802271, '149': 1.443063442139042, '77': 0.00098632725773375595, '76': 0.00066992367951815681, '75': 0.0002489289301356163, '74': 0.00014303434449076732, '73': 3.9165029477732167e-05, '72': 3.4821089488027778e-05, '71': 1.3389861887997911e-05, '70': 3.4796690028361379e-06, '79': 0.0040640984663206049, '78': 0.0021762640339149865}
# ['165', '133', '132', '131', '130', '137', '136', '135', '134', '139', '138', '166', '167', '160', '161', '162', '163', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '59', '55', '57', '56', '164', '179', '178', '115', '114', '88', '89', '111', '110', '113', '112', '82', '83', '80', '81', '86', '87', '84', '85', '108', '109', '102', '103', '100', '101', '106', '107', '104', '105', '177', '176', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '175', '174', '173', '172', '171', '170', '182', '183', '99', '98', '168', '169', '91', '90', '93', '92', '95', '94', '97', '96', '117', '116', '151', '150', '153', '152', '155', '154', '157', '156', '159', '158', '119', '118', '146', '147', '144', '145', '142', '143', '140', '141', '148', '149', '77', '76', '75', '74', '73', '72', '71', '70', '79', '78']
# 46
# 47

# %%
print w
print fy
# Out:
# [0.028406001194131756, 0.0043175861148899873, 0, 8.6010752193189593e-06, 8.6010752193189593e-06, 8.6010752193189593e-06, 8.6010752193189593e-06, 6.4073848757584365e-05, 0.00020359549945658432, 0.00020359549945658432, 0.000369123635218515, 0.037898350932717907, 0.069825580465170525, 0.036570384598068231, 0.069636964198285245, 0.0076424885486602694, 8.6010752193189593e-06, 0.066044469121440935, 2.9623889347558109e-05, 2.9286530181199713e-07, 0.05444928369513085, 0.00062822586487117451, 0.00020359549945658432, 0.010338964934742428, 0.00094097603420496096, 0.046655114145691318, 0.042514914998281493, 0.0042431059528894692, 0.0011370994057547706, 0.0005149780206111105, 0.01795974718152853, 0.0018194422715777023, 0.061172509495373582, 5.4681065841581069e-05, 5.3914788996907653e-06, 0.02366305748109148, 1.9491349022988695e-06, 0.029972333736203054, 0.062116595384727677, 0.00026364120285573536, 0.002915987836714715, 0.011588123218504635, 0.052985087134859957, 1.5989362406610427e-05, 0.067751121312325621, 0.00012614997607061465, 0.068213270579532914, 0.0019306958939835264, 0.017656509351077508, 0.02112721755560577, 0.069369318010503778, 0.0067278043940518836]
# [6.057, 4.9137, 6.0257, 4.4631, 5.1096, 5.3626, 6.0998, 6.1334, 6.076, 6.0774, 6.0835, 6.0376, 5.8775, 5.2831, 5.9015, 4.8936, 4.4705, 5.7926, 4.4775, 3.9821, 5.9886, 6.069, 6.0323, 4.9859, 5.0098, 6.0393, 5.3436, 6.0537, 6.0102, 4.7684, 5.0107, 5.2299, 5.5535, 4.4241, 4.4231, 6.0651, 4.254, 5.2027, 5.965, 4.666, 6.0949, 6.0987, 5.4723, 4.5572, 5.9351, 4.5098, 5.827, 6.0624, 6.0263, 6.0607, 5.8785, 6.0683]

# %%
# Output the result
outfn="238U_watt_sum_fy.csv"

def writeout(outfn,outl):  # function to write our output in csv format
    ofile = open(outfn,"w")

    for out in outl:
        ofile.write(str(out[0])
                    + "," + str(out[1])
                    + "," + str(out[2])
                    + "," + str(sqrt(out[3]))
                    + "," + str(out[4])
                    + "\n")

    ofile.close()

outl=[]
for A in y.keys():
    outl.append((A,0,y[A],err[A]," "))
writeout(outfn,outl)
